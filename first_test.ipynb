# %% [markdown]
# <a href="https://colab.research.google.com/github/daveedortega/google_colab/blob/main/first_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Hello Python!
# This is us getting back at it! In't it great?
# I lovew the fact that i do not have to code it inside my dumb machine and can do it in google cloud.
#
# I will use this for:
#
# 1. General Python Practive
# 2. My MIT course work
#
# But **NOT** For my work.
#
# I still need to figure VisStudioCode Jupyter.
#
# Anyhow, here we go!

# %%
from typing import Counter
import pandas as pd
import numpy as np

print('Hello World')

for i in range(1,10,1):
  print(i);
# Out:
# Hello World
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %% [markdown]
# ## Playing with dataframes and pandas and numpy
# I barely remember how to do things like filter and what not so this is a good chance to remember it all.

# %%
# Enable interactive df look
from google.colab import data_table
data_table.enable_dataframe_formatter()

from vega_datasets import data
import pandas as pd
import numpy as np

# %%
df_jobs = data.jobs()
df_jobs.head()
# Out:
#                     job  sex  year  count      perc
# 0  Accountant / Auditor  men  1850    708  0.000131
# 1  Accountant / Auditor  men  1860   1805  0.000214
# 2  Accountant / Auditor  men  1870   1310  0.000100
# 3  Accountant / Auditor  men  1880   2295  0.000125
# 4  Accountant / Auditor  men  1900  11753  0.000396

# %%
df_cars = data.cars()
df_cars.head()
# Out:
#                         Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0  chevrolet chevelle malibu              18.0          8         307.0
# 1          buick skylark 320              15.0          8         350.0
# 2         plymouth satellite              18.0          8         318.0
# 3              amc rebel sst              16.0          8         304.0
# 4                ford torino              17.0          8         302.0
#
#    Horsepower  Weight_in_lbs  Acceleration       Year Origin
# 0       130.0           3504          12.0 1970-01-01    USA
# 1       165.0           3693          11.5 1970-01-01    USA
# 2       150.0           3436          11.0 1970-01-01    USA
# 3       150.0           3433          12.0 1970-01-01    USA
# 4       140.0           3449          10.5 1970-01-01    USA

# %%
# Filter cars with 8 cylinders
car_8c = df_cars[df_cars['Cylinders']==8]

print('Average miles per galon in 8 cylinder cars: ',car_8c['Miles_per_Gallon'].mean().round(2))
# Out:
# Average miles per galon in 8 cylinder cars:  14.96

# %%
car_8c
# Out:
#                                      Name  Miles_per_Gallon  Cylinders  \
# 0               chevrolet chevelle malibu              18.0          8
# 1                       buick skylark 320              15.0          8
# 2                      plymouth satellite              18.0          8
# 3                           amc rebel sst              16.0          8
# 4                             ford torino              17.0          8
# ..                                    ...               ...        ...
# 298         chevrolet malibu classic (sw)              19.2          8
# 299  chrysler lebaron town @ country (sw)              18.5          8
# 305                     cadillac eldorado              23.0          8
# 307     oldsmobile cutlass salon brougham              23.9          8
# 372                 oldsmobile cutlass ls              26.6          8
#
#      Displacement  Horsepower  Weight_in_lbs  Acceleration       Year Origin
# ...

# %% [markdown]
# # This is a Bunch or Markdown
# ## Idk i mean i guess it is cool
#
# >_What to do with MD_
#
# >>**Who knows**
#
# 1. Type anywhere with some indentation
# 1. With some style
# 1. With general help
#
# Other things:
# * Works anywhere, python, colab, github, anywhere
# * Or does it? :/
#
# $\delta s = \frac{v_2 - v_1}{x_2 - x_1}$
#
# $U_i = ln(x_1) + ln_(x_2)$
#
# ``` for i in range(19): print(i, 'HW')```
